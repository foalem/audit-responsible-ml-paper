# %%
import pandas as pd

# %%
df_1 = pd.read_excel("Full List of ML Products and Sample.xlsx")
df_2 = pd.read_csv("repo-metadata.csv")

# %%
df_1
# Out:
#                                        Name  \
# 0                       renard314/textfairy
# 1        SmartReceipts/SmartReceiptsLibrary
# 2    openfoodfacts/openfoodfacts-androidapp
# 3              projectmatris/antimalwareapp
# 4                        the-dagger/Pokidex
# ..                                      ...
# 257                         carrot2/carrot2
# 258                    triplea-game/triplea
# 259                WiproOpenSource/openbdre
# 260                         OCR4all/OCR4all
# 261             mit-cml/appinventor-sources
#
#                                                Link(s)  \
# 0               https://github.com/renard314/textfairy
# 1    https://github.com/SmartReceipts/SmartReceipts...
# 2    https://github.com/openfoodfacts/openfoodfacts...
# 3      https://github.com/projectmatris/antimalwareapp
# 4                https://github.com/the-dagger/Pokidex
# ..                                                 ...
# ...

# %%
df_2
# Out:
#      Category     ght_id                         full_name               name  \
# 0     Applied  122869414                    42-AI/rdvmaths           rdvmaths
# 1     Applied  110144268                 AVAuco/ssd_people         ssd_people
# 2     Applied  128040792         awslabs/datawig-sagemaker  datawig-sagemaker
# 3     Applied   94736906                 bcbi/PredictMD.jl       PredictMD.jl
# 4     Applied  125887810  betterweb-team/BetterWeb-Backend  BetterWeb-Backend
# ...       ...        ...                               ...                ...
# 9320     Tool  131634055                ddbourgin/numpy-ml           numpy-ml
# 9321     Tool   69312048         eriklindernoren/Keras-GAN          Keras-GAN
# 9322     Tool    7776438                    davisking/dlib               dlib
# 9323     Tool   12579794             gunthercox/ChatterBot         ChatterBot
# 9324     Tool   58981828         ageitgey/face_recognition   face_recognition
#
# ...

# %%
df_2 = df_2[df_2["Category"] == "Applied"]
df_2
# Out:
#      Category     ght_id                         full_name  \
# 0     Applied  122869414                    42-AI/rdvmaths
# 1     Applied  110144268                 AVAuco/ssd_people
# 2     Applied  128040792         awslabs/datawig-sagemaker
# 3     Applied   94736906                 bcbi/PredictMD.jl
# 4     Applied  125887810  betterweb-team/BetterWeb-Backend
# ...       ...        ...                               ...
# 4519  Applied  117144739    emilwallner/Screenshot-to-code
# 4520  Applied   46926518        mxgmn/WaveFunctionCollapse
# 4521  Applied    9419195                      ty4z2008/Qix
# 4522  Applied   18025548                      hankcs/HanLP
# 4523  Applied   83460809                deepfakes/faceswap
#
#                       name           Owner  owner_id          Date Created  \
# 0                 rdvmaths           42-AI  39668504  2019-01-13T14:27:50Z
# 1               ssd_people          AVAuco  44834801  2018-09-16T18:56:38Z
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4524 entries, 0 to 4523
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Category             4524 non-null   object
#  1   ght_id               4524 non-null   int64
#  2   full_name            4524 non-null   object
#  3   name                 4524 non-null   object
#  4   Owner                4524 non-null   object
#  5   owner_id             4524 non-null   int64
#  6   Date Created         4524 non-null   object
#  7   Date of Last Commit  4524 non-null   object
#  8   Date Last Updated    4524 non-null   object
#  9   Owner Type           4524 non-null   object
#  10  Forks                4524 non-null   int64
#  11  Stars                4524 non-null   int64
#  12  Subscribers          4524 non-null   int64
#  13  Size                 4524 non-null   int64
#  14  Open Issues          4524 non-null   int64
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  262 non-null    object
#  1   Link(s)               262 non-null    object
#  2   Description           262 non-null    object
#  3   Have ML?              259 non-null    object
#  4   End user app?         261 non-null    object
#  5   Found in?             262 non-null    object
#  6   Appears more like...  262 non-null    object
#  7   Stars                 262 non-null    int64
#  8   Contributors          262 non-null    int64
#  9   CodeBase Size         262 non-null    int64
# dtypes: int64(3), object(7)
# memory usage: 20.6+ KB

# %%
df_2 = df_2[['full_name', 'Stars']]
df_2 = df_2.rename(columns={'full_name':'repository_full_name'})
df_2
# Out:
#                   repository_full_name  Stars
# 0                       42-AI/rdvmaths      5
# 1                    AVAuco/ssd_people      5
# 2            awslabs/datawig-sagemaker      5
# 3                    bcbi/PredictMD.jl      5
# 4     betterweb-team/BetterWeb-Backend      5
# ...                                ...    ...
# 4519    emilwallner/Screenshot-to-code  11698
# 4520        mxgmn/WaveFunctionCollapse  12105
# 4521                      ty4z2008/Qix  12698
# 4522                      hankcs/HanLP  13819
# 4523                deepfakes/faceswap  20477
#
# [4524 rows x 2 columns]

# %%
df_1 = df_1[['Name', 'Stars']]
df_1 = df_1.rename(columns={'Name': 'repository_full_name'})
df_1
# Out:
#                        repository_full_name  Stars
# 0                       renard314/textfairy    751
# 1        SmartReceipts/SmartReceiptsLibrary    233
# 2    openfoodfacts/openfoodfacts-androidapp    693
# 3              projectmatris/antimalwareapp    205
# 4                        the-dagger/Pokidex    166
# ..                                      ...    ...
# 257                         carrot2/carrot2    637
# 258                    triplea-game/triplea    535
# 259                WiproOpenSource/openbdre     52
# 260                         OCR4all/OCR4all    187
# 261             mit-cml/appinventor-sources   1329
#
# [262 rows x 2 columns]

# %%
frames = [df_1, df_2]
result = pd.concat(frames).reset_index(drop=True)
result
# Out:
#                         repository_full_name  Stars
# 0                        renard314/textfairy    751
# 1         SmartReceipts/SmartReceiptsLibrary    233
# 2     openfoodfacts/openfoodfacts-androidapp    693
# 3               projectmatris/antimalwareapp    205
# 4                         the-dagger/Pokidex    166
# ...                                      ...    ...
# 4781          emilwallner/Screenshot-to-code  11698
# 4782              mxgmn/WaveFunctionCollapse  12105
# 4783                            ty4z2008/Qix  12698
# 4784                            hankcs/HanLP  13819
# 4785                      deepfakes/faceswap  20477
#
# [4786 rows x 2 columns]

# %%
result.to_csv('ML_project_dataset.csv', sep=',', encoding='utf-8', index=False)
